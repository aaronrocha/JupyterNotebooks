# %%
from sympy import *
x, y, z, t = symbols('x y z t')

# %%
p11 = 3 / (x**2 + x + 1)
p11
# Out:
# 3/(x**2 + x + 1)

# %% [markdown]
# The reciprocal Rule to find the derivative.

# %% [markdown]
#  1 / f(x) = -f`(x) / [ f(x) ]^2

# %%
 -3*(2*x + 1) / (x**2 + x + 1)**2
# Out:
# (-6*x - 3)/(x**2 + x + 1)**2

# %% [markdown]
# Now let's see if the computer agrees.  Using the diff function of sympy.

# %%
diff(p11)
# Out:
# 3*(-2*x - 1)/(x**2 + x + 1)**2

# %%
plot(p11, (x, -5, 5))

# %%
solveset(Eq(Out[5], 0), x)
# Out:
# FiniteSet(-1/2)

# %%
Out[5].subs(x, -1/2)
# Out:
# 0

# %%
p11.subs(x, -1/2)
# Out:
# 4.00000000000000

# %% [markdown]
# Now we have a point where the derivative of our function will equal zero.  We know that is when the slope is zero.  So now we can use our point-slope to find the graph of the tangent line at (-1/2, 4).

# %%
Eq(y-4, 0*(x + 1/2))
# Out:
# Eq(y - 4, 0)

# %%
plot(p11, 4,  (x, -5, 5))
