# %%
from sympy import *
x, y, z = symbols("x y z")

# %%
expr = x**3 - 3 * x**2 + 1

# %%
expr
# Out:
# x**3 - 3*x**2 + 1

# %%
import numpy
a = numpy.arange(-0.55, 3.0, 0.10)
f = lambdify(x, expr, "numpy")
f(a)
# Out:
# array([-0.073875,  0.301375,  0.589625,  0.796875,  0.929125,  0.992375,
#         0.992625,  0.935875,  0.828125,  0.675375,  0.483625,  0.258875,
#         0.007125, -0.265625, -0.553375, -0.850125, -1.149875, -1.446625,
#        -1.734375, -2.007125, -2.258875, -2.483625, -2.675375, -2.828125,
#        -2.935875, -2.992625, -2.992375, -2.929125, -2.796875, -2.589625,
#        -2.301375, -1.926125, -1.457875, -0.890625, -0.218375,  0.564875])

# %%
a
# Out:
# array([-0.55, -0.45, -0.35, -0.25, -0.15, -0.05,  0.05,  0.15,  0.25,
#         0.35,  0.45,  0.55,  0.65,  0.75,  0.85,  0.95,  1.05,  1.15,
#         1.25,  1.35,  1.45,  1.55,  1.65,  1.75,  1.85,  1.95,  2.05,
#         2.15,  2.25,  2.35,  2.45,  2.55,  2.65,  2.75,  2.85,  2.95])

# %%
N(solveset(expr,x))
# Out:
# FiniteSet(-0.532088886237956, 0.652703644666139, 2.87938524157182)

# %%
from sympy.plotting import plot

# %%
p1 = plot(expr, (x, -1, 3) ,show=False)

# %%
p1.show()

# %%
?
